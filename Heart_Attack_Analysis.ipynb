# %% [markdown]
# # Heart Attack Data Analysis

# %% [markdown]
# Importing Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter

# %%
heartattack_data = pd.read_csv("C:\\Users\\Sowmya Surampalli\\Downloads\\datasets_727551_1263738_heart_failure_clinical_records_dataset.csv")

# %%
heartattack_data.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %%
heartattack_data.shape
# Out:
# (299, 13)

# %%
heartattack_data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
heartattack_data.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
heartattack_data.drop('time',1,inplace=True)

# %% [markdown]
# ## EDA

# %% [markdown]
# Checking for null values

# %%
100*heartattack_data.isnull().sum()/len(heartattack_data)
# Out:
# age                         0.0
# anaemia                     0.0
# creatinine_phosphokinase    0.0
# diabetes                    0.0
# ejection_fraction           0.0
# high_blood_pressure         0.0
# platelets                   0.0
# serum_creatinine            0.0
# serum_sodium                0.0
# sex                         0.0
# smoking                     0.0
# DEATH_EVENT                 0.0
# dtype: float64

# %%
heartattack_data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
sns.pairplot(heartattack_data,hue='DEATH_EVENT',aspect=0.8)
# Out:
# C:\Users\Sowmya Surampalli\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Sowmya Surampalli\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
plt.figure(figsize=(20,6))
sns.heatmap(heartattack_data.corr(),annot=True)

# %% [markdown]
# #### Effect of Age on Heart attack

# %%
fig,ax = plt.subplots(1,2,figsize=(20,7))
ax[0].hist(heartattack_data.age,color='orange',edgecolor='black')
ax[0].set_title("Age Distribution")
ax[0].set_xlabel("Age")
ax[0].set_ylabel("No. of people")
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['age'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['age']],
        stacked=True,color=['blue','orange'],edgecolor='black',label=["dead","survived"])
ax[1].set_xlabel("Age")
ax[1].set_ylabel("No. of people")
# Out:
# Text(0, 0.5, 'No. of people')

# %% [markdown]
# Insights:

# %%
fig,ax = plt.subplots(1,2,figsize=(20,7))
##plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
ax[0].hist(heartattack_data.age,
           color='orange',
           edgecolor='black')
ax[0].set_title("Age Distribution")
ax[0].set_xlabel("Age")
ax[0].set_ylabel("No. of people")
len1 = len(heartattack_data[heartattack_data['DEATH_EVENT']==1])
len2 = len(heartattack_data[heartattack_data['DEATH_EVENT']==0])
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['age'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['age']],
           stacked=True,
           color=['blue','orange'],
           edgecolor='black',
           label=["dead","survived"])
ax[1].set_xlabel("Age")
ax[1].set_ylabel("No. of people")
# Out:
# Text(0, 0.5, 'No. of people')

# %% [markdown]
# #### Effect of Anemia on Heart Attack

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['anaemia'],
           color='orange',
          label='Patients',
          edgecolor='black')
ax[0].set_xticks([0,1])
ax[0].set_xticklabels(['No Anaemia','Has Anaemia'])
ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['anaemia'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['anaemia']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )
ax[1].set_xticks([0,1])
ax[1].set_xticklabels(['No Anaemia','Has Anaemia'])
ax[1].legend()

# %% [markdown]
# #### Effect of level of creatinine_phosphokinase

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['creatinine_phosphokinase'],
           color='orange',
          label='Patients',
          edgecolor='black')

ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['creatinine_phosphokinase'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['creatinine_phosphokinase']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )
# Out:
# ([array([83.,  5.,  3.,  1.,  0.,  1.,  0.,  1.,  0.,  2.]),
#   array([252.,  21.,  13.,   6.,   0.,   3.,   1.,   1.,   0.,   2.])],
#  array([  23. ,  806.8, 1590.6, 2374.4, 3158.2, 3942. , 4725.8, 5509.6,
#         6293.4, 7077.2, 7861. ]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['creatinine_phosphokinase'],heartattack_data['DEATH_EVENT'])
plt.title('creatinine_phosphokinase levels and chance of death')
# Out:
# Text(0.5, 1.0, 'creatinine_phosphokinase levels and chance of death')

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['creatinine_phosphokinase'],heartattack_data['age'])
plt.title('creatinine_phosphokinase levels and age')
# Out:
# Text(0.5, 1.0, 'creatinine_phosphokinase levels and age')

# %% [markdown]
# #### Effect of Diabetes

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['diabetes'],
           color='orange',
          label='Patients',
          edgecolor='black')
ax[0].set_xticks([0,1])
ax[0].set_xticklabels(['No Diabetes','Has Diabetes'])
ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['diabetes'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['diabetes']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )
ax[1].set_xticks([0,1])
ax[1].set_xticklabels(['No Diabetes','Has Diabetes'])
ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['diabetes'],heartattack_data['DEATH_EVENT'])
plt.title('diabetes and chance of death')
# Out:
# Text(0.5, 1.0, 'diabetes and chance of death')

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['high_blood_pressure'],
           color='orange',
          label='Patients',
          edgecolor='black')
ax[0].set_xticks([0,1])
ax[0].set_xticklabels(['Normal blood pressure','High blood pressure'])
ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['high_blood_pressure'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['high_blood_pressure']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )
ax[1].set_xticks([0,1])
ax[1].set_xticklabels(['Normal blood pressure','High blood pressure'])
ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['high_blood_pressure'],heartattack_data['DEATH_EVENT'])
plt.title('high_blood_pressure and chance of death')
# Out:
# Text(0.5, 1.0, 'high_blood_pressure and chance of death')

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['ejection_fraction'],
           color='orange',
          label='Patients',
          edgecolor='black')

ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['ejection_fraction'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['ejection_fraction']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )

ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['ejection_fraction'],heartattack_data['DEATH_EVENT'])
plt.title('ejection_fraction and chance of death')
# Out:
# Text(0.5, 1.0, 'ejection_fraction and chance of death')

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['platelets'],
           color='orange',
          label='Patients',
          edgecolor='black')

ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['platelets'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['platelets']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )

ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['platelets'],heartattack_data['DEATH_EVENT'])
plt.title('platelets and chance of death')
# Out:
# Text(0.5, 1.0, 'platelets and chance of death')

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['serum_creatinine'],
           color='orange',
          label='Patients',
          edgecolor='black')

ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['serum_creatinine'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['serum_creatinine']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )

ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['serum_creatinine'],heartattack_data['DEATH_EVENT'])
plt.title('serum_creatinine and chance of death')
# Out:
# Text(0.5, 1.0, 'serum_creatinine and chance of death')

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].hist(heartattack_data['serum_sodium'],
           color='orange',
          label='Patients',
          edgecolor='black')

ax[0].legend()
ax[1].hist(x=[heartattack_data[heartattack_data['DEATH_EVENT']==1]['serum_sodium'],heartattack_data[heartattack_data['DEATH_EVENT']==0]['serum_sodium']],
           color=['blue','orange'],
           stacked=True,
           label=['Dead','Recovered'],
           edgecolor='black'
          )

ax[1].legend()

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['smoking'],heartattack_data['DEATH_EVENT'])
plt.title('smoking and chance of death')
# Out:
# Text(0.5, 1.0, 'smoking and chance of death')

# %%
plt.figure(figsize=(15,6))
sns.regplot(heartattack_data['serum_sodium'],heartattack_data['serum_creatinine'])
plt.title('serum_sodium and age')
# Out:
# Text(0.5, 1.0, 'serum_sodium and age')

# %% [markdown]
# ## Decision Tree

# %%
heartattack_data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'DEATH_EVENT'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# ### Feature Selection

# %%
feature_cols = ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking']
X = heartattack_data[feature_cols] # Features
y = heartattack_data.DEATH_EVENT # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# ### Building a Decision Tree

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6888888888888889

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77        64
#            1       0.47      0.54      0.50        26
#
#     accuracy                           0.69        90
#    macro avg       0.63      0.64      0.64        90
# weighted avg       0.70      0.69      0.69        90

# %%
print(metrics.confusion_matrix(y_test,y_pred))
# Out:
# [[48 16]
#  [12 14]]

# %% [markdown]
# ## Logistic Regression

# %%
import statsmodels.api as sm

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# C:\Users\Sowmya Surampalli\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            DEATH_EVENT   No. Observations:                  209
# Model:                            GLM   Df Residuals:                      197
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -103.44
# Date:                Wed, 07 Oct 2020   Deviance:                       206.89
# Time:                        00:07:37   Pearson chi2:                     231.
# No. Iterations:                     5
# ...

# %%
col =  ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['Features'] = X_train[col].columns
vif['VIF'] = [variance_inflation_factor(X_train[col].values, i) for i in range(X_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                     Features    VIF
# 8               serum_sodium  49.42
# 0                        age  27.61
# 4          ejection_fraction  12.20
# 6                  platelets   8.92
# 9                        sex   3.76
# 7           serum_creatinine   2.70
# 1                    anaemia   1.99
# 10                   smoking   1.84
# 3                   diabetes   1.78
# 5        high_blood_pressure   1.65
# 2   creatinine_phosphokinase   1.38

# %%
col =  ['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'sex', 'smoking']

# %%
X_train.drop(['serum_sodium'],axis=1,inplace=True)
# Out:
# C:\Users\Sowmya Surampalli\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# C:\Users\Sowmya Surampalli\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            DEATH_EVENT   No. Observations:                  209
# Model:                            GLM   Df Residuals:                      198
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -104.26
# Date:                Wed, 07 Oct 2020   Deviance:                       208.52
# Time:                        00:12:01   Pearson chi2:                     233.
# No. Iterations:                     5
# ...

# %%
vif = pd.DataFrame()
vif['Features'] = X_train[col].columns
vif['VIF'] = [variance_inflation_factor(X_train[col].values, i) for i in range(X_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                    Features    VIF
# 0                       age  16.14
# 4         ejection_fraction   9.44
# 6                 platelets   7.70
# 8                       sex   3.58
# 7          serum_creatinine   2.68
# 1                   anaemia   1.95
# 9                   smoking   1.83
# 3                  diabetes   1.70
# 5       high_blood_pressure   1.65
# 2  creatinine_phosphokinase   1.35
